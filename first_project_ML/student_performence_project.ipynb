# %%
pip install gradio

# %%
import numpy as np
import gradio as gr
import pandas as pd
import matplotlib.pyplot as plt
import seaborn  as sns

# %%
data = pd.read_csv("/content/sample_data/studentPerformance.csv")
data
# Out:
#      Study_Hours  Attendance  Practice_Tests  Final_Score  Pass_Fail
# 0       3.745401   59.256646               1    53.580408          1
# 1       9.507143   77.095047               2    84.990141          1
# 2       7.319939   93.647292               3   100.000000          1
# 3       5.986585   86.611244               1    76.978847          1
# 4       1.560186   90.328057               0    46.875418          0
# ..           ...         ...             ...          ...        ...
# 495     3.533522   83.410640               1    50.488596          1
# 496     5.836561   80.974517               0    65.307977          1
# 497     0.777346   73.174702               1    48.149568          0
# 498     9.743948   68.989289               4   100.000000          1
# 499     9.862107   93.166682               2   100.000000          1
#
# [500 rows x 5 columns]

# %% [markdown]
# # Nouvelle section

# %%
data.isnull().sum()
#our data is clean from NONE value#
# Out:
# Study_Hours       0
# Attendance        0
# Practice_Tests    0
# Final_Score       0
# Pass_Fail         0
# dtype: int64

# %%
data.shape
# Out:
# (500, 5)

# %%
data.dtypes
# Out:
# Study_Hours       float64
# Attendance        float64
# Practice_Tests      int64
# Final_Score       float64
# Pass_Fail           int64
# dtype: object

# %%
x=data[['Study_Hours','Attendance','Practice_Tests']]
y=data['Final_Score']
print(x.head() ,"\n"*3) ,
y.head()
# Out:
#    Study_Hours  Attendance  Practice_Tests
# 0     3.745401   59.256646               1
# 1     9.507143   77.095047               2
# 2     7.319939   93.647292               3
# 3     5.986585   86.611244               1
# 4     1.560186   90.328057               0
# 0     53.580408
# 1     84.990141
# 2    100.000000
# 3     76.978847
# 4     46.875418
# Name: Final_Score, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain , xtest, ytrain , ytest=train_test_split(x, y , test_size =0.1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypredict= model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest , ypredict)
# Out:
# 3.8275146217756935

# %%
model_error=mean_absolute_error(ytest , ypredict)/ytest.mean()
print(f"### our model’s error rate is {model_error * 100:.2f}% ###")
# Out:
# ### our model’s error rate is 5.84% ###

# %%
def predict(Study_Hours1 ,Attendance1, Practice_Tests1 ):
  try:
    student_data = [[Study_Hours1, Attendance1, Practice_Tests1]]
    predicted_score = model.predict(student_data)[0]
    predicted_score = max(0, min(100, predicted_score))
    return f"\n✅Predicted Final Score: {predicted_score:.2f}\nLikely to pass: {'🎉🥳Yes , Pass_fail take 1 ' if predicted_score >= 50 else '🥺🥀No , Pass_Fail take 0'}"
  except Exception as e:
    return f"ERROR❌ :{e}"

# %%
iface = gr.Interface(
    fn=predict,
    inputs=[
        gr.Number(label="Study_Hours"),
        gr.Number(label="Attendance"),
        gr.Number(label="Practice_Tests"),
    ],
    outputs=gr.Text(label="Final_Score and Pass_Fail"),
    title ="STUDENT PERFORMENCE",
    description ="enter a three value to predict the result of our student",




)
iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://46da5254e604bd74c3.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://46da5254e604bd74c3.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# To install a Python library in Google Colab, you can use the `pip` package installer. Simply run the following command in a code cell, replacing `library_name` with the name of the library you want to install:

# %%
# %pip install library_name
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ERROR: Could not find a version that satisfies the requirement library_name (from versions: none)
# ERROR: No matching distribution found for library_name

# %% [markdown]
# For example, to install the `requests` library, you would run:

# %%
# %pip install requests

# %% [markdown]
# The `%pip` magic command is recommended in Colab notebooks as it ensures that the library is installed in the correct environment and will be available for use in subsequent cells.
