# %%
import numpy as np 
import pandas as pd 
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("CC GENERAL.csv")
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
data["MINIMUM_PAYMENTS"]=data["MINIMUM_PAYMENTS"].fillna(data["MINIMUM_PAYMENTS"].mean() )
data["CREDIT_LIMIT"]=data["CREDIT_LIMIT"].fillna(data["CREDIT_LIMIT"].mean() )
data.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
x=data.iloc[:,[1,3]]
x.head()
# Out:
#        BALANCE  PURCHASES
# 0    40.900749      95.40
# 1  3202.467416       0.00
# 2  2495.148862     773.17
# 3  1666.670542    1499.00
# 4   817.714335      16.00

# %%
means=KMeans(3)
means.fit(x)
# Out:
# KMeans(n_clusters=3)

# %%
identified_clusters=means.fit_predict(x)
identified_clusters
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
data_with_clust = data.copy()
data_with_clust['Clusters']=identified_clusters
plt.scatter(data_with_clust['BALANCE'],data_with_clust['PURCHASES'],c= data_with_clust['Clusters'],cmap='rainbow')
